# %% [markdown]
# # Import Library

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Deklarasi Modul

# %% [markdown]
# ## Inisialisasi Dataset

# %%
df = pd.read_csv("datasets/covid_19_indonesia.csv")

# %% [markdown]
# ## Show Dataset

# %%
pd.DataFrame(df)
# Out:
#             Date Location ISO Code           Location  New Cases  New Deaths  \
# 0       1/8/2020             ID-JI         Jawa Timur          9           3
# 1       1/9/2020             ID-JI         Jawa Timur          0           1
# 2      1/10/2020             ID-JI         Jawa Timur          0           1
# 3      1/11/2020             ID-JI         Jawa Timur          0           3
# 4      1/12/2020             ID-JI         Jawa Timur          0           3
# ...          ...               ...                ...        ...         ...
# 16278   7/9/2021             ID-SG  Sulawesi Tenggara        124           1
# 16279   7/9/2021             ID-SA     Sulawesi Utara        278           9
# 16280   7/9/2021             ID-SB     Sumatera Barat        718          10
# 16281   7/9/2021             ID-SS   Sumatera Selatan        341           6
# 16282   7/9/2021             ID-SU     Sumatera Utara        336           5
#
# ...

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Drop Column
# drop Kolom yang tidak berguna

# %%
df.drop(["Province", "Country", "Continent", "Island", "Time Zone", 
                "Special Status", "Total Regencies", "Total Cities", "Total Districts", "Total Urban Villages", "Total Rural Villages", "Area (km2)", 
                "New Cases per Million", "Total Cases per Million","New Deaths per Million", "Total Deaths per Million", "Case Fatality Rate",
                "Case Recovered Rate", "Growth Factor of New Cases","Growth Factor of New Deaths", "City or Regency"],axis=1,inplace=True)

# %% [markdown]
# ## Rename Column

# %% [markdown]
# nama variabel tidak boleh ada spasi jika dalam program <br>
# makanya ini kita akan melakukan Rename Kolom pada dataset<br>
# <li>CamelCase
# <li>snake_case

# %% [markdown]
# ### Before

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16283 entries, 0 to 16282
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                16283 non-null  object
#  1   Location            16283 non-null  object
#  2   New Cases           16283 non-null  int64
#  3   New Deaths          16283 non-null  int64
#  4   New Recovered       16283 non-null  int64
#  5   New Active Cases    16283 non-null  int64
#  6   Total Cases         16283 non-null  int64
#  7   Total Deaths        16283 non-null  int64
#  8   Total Recovered     16283 non-null  int64
#  9   Total Active Cases  16283 non-null  int64
#  10  Location Level      16283 non-null  object
#  11  Population          16283 non-null  int64
#  12  Population Density  16283 non-null  float64
#  13  Longitude           16283 non-null  float64
#  14  Latitude            16283 non-null  float64
# ...

# %% [markdown]
# ### process

# %%
df_renamed = df.rename(columns = {
    'Date' : 'tanggal',
    'Location ISO Code' : 'location_iso_code',
    'Location' : 'provinsi',
    'New Cases' : 'new_cases',
    'New Deaths' : 'new_deaths',
    'New Recovered' : 'new_recovered',
    'New Active Cases' : 'new_active_cases',
    'Total Cases' : 'total_kasus',
    'Total Deaths' : 'total_kematian',
    'Total Recovered' : 'total_pulih',
    'Total Active Cases' : 'total_kasus_aktif',
    'Location Level' : 'location_level',
    'Population':'populasi',
    'Population Density':'kepadatan_populasi',
    'Longitude':'garis_bujur',
    'Latitude':'garis_lintang',
    'Name':'nama',
    'Item':'item',
    'Kind':'jenis',
    'Hidden':'disembunyikan'
    
})

# %% [markdown]
# ### After

# %%
df_renamed.head()
# Out:
#      tanggal    provinsi  new_cases  new_deaths  new_recovered  \
# 0   1/8/2020  Jawa Timur          9           3              1
# 1   1/9/2020  Jawa Timur          0           1             23
# 2  1/10/2020  Jawa Timur          0           1             14
# 3  1/11/2020  Jawa Timur          0           3              8
# 4  1/12/2020  Jawa Timur          0           3              1
#
#    new_active_cases  total_kasus  total_kematian  total_pulih  \
# 0                 5            9               5           10
# 1               -24            9               6           33
# 2               -15            9               7           47
# 3               -11            9              10           55
# 4                -4            9              13           56
#
#    total_kasus_aktif location_level  populasi  kepadatan_populasi  \
# 0                 -6       Province  40479023              846.78
# 1                -30       Province  40479023              846.78
# ...

# %% [markdown]
# ## Convert Type, Obj to Date for Column Date

# %%
# convert Date column to date type
df_renamed["tanggal"] = pd.to_datetime(df_renamed["tanggal"])

# %% [markdown]
# ## Check Duplicate

# %%
df_renamed[df_renamed.duplicated()].sum()
# Out:
# provinsi              0.0
# new_cases             0.0
# new_deaths            0.0
# new_recovered         0.0
# new_active_cases      0.0
# total_kasus           0.0
# total_kematian        0.0
# total_pulih           0.0
# total_kasus_aktif     0.0
# location_level        0.0
# populasi              0.0
# kepadatan_populasi    0.0
# garis_bujur           0.0
# garis_lintang         0.0
# nama                  0.0
# item                  0.0
# jenis                 0.0
# disembunyikan         0.0
# dtype: float64

# %% [markdown]
# ## Check Missing Data

# %%
df_renamed.isnull().sum()
# Out:
# tanggal                   0
# provinsi                  0
# new_cases                 0
# new_deaths                0
# new_recovered             0
# new_active_cases          0
# total_kasus               0
# total_kematian            0
# total_pulih               0
# total_kasus_aktif         0
# location_level            0
# populasi                  0
# kepadatan_populasi        0
# garis_bujur               0
# garis_lintang             0
# nama                  16283
# item                  16283
# jenis                 16283
# disembunyikan         16283
# dtype: int64

# %% [markdown]
# # Visualization

# %%
df_renamed[['']]

# %% [markdown]
# ## Total_cases & total_deaths

# %%
#IDN
kasus_yg_dikonfimasi = data[data['location_iso_code']=='IDN'].groupby(['tanggal']).agg({'total_kasus':['sum']})
kematian_berdasarkan_tanggal = data[data['location_iso_code']=='IDN'].groupby(['tanggal']).agg({'total_kematian':['sum']})
total_date_IDN= ConfirmedCases_date_IDN.join(kematian_berdasarkan_tanggal)


plt.figure(figsize=(15,10))
plt.subplot(2, 2, 1)
total_date_IDN.plot(ax=plt.gca(), title='Indonesia')
